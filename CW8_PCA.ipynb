# %% [markdown]
# # **"FaceValue": The Biometric Compression Challenge**
#
# ### **The Scenario**
#
# You are a lead engineer at **"FaceValue,"** a security startup. Your team needs to store thousands of high-resolution employee face scans on low-power hardware. Storing raw pixels is too expensive. You must use **Principal Component Analysis (PCA)** to find the "Eigen-faces"—the fundamental patterns that make up a human face—and use them to compress the images.

# %% [markdown]
# ### **Part 1: Conceptual Stress-Tests**

# %% [markdown]
# >**How to approach these questions:**
# >* **Q1:** Think about the definition of the 1st Principal Component. If variance is identical in all directions, can the math "choose" a winner?
# >
# >
# > * **Q2:** PCA is sensitive to the *magnitude* of numbers. Consider what happens if one feature has a range of 10,000 and another has a range of 10.

# %% [markdown]
# **Question 1: The "Spherical" Data Problem**
# Suppose your dataset is a perfect 2D circle of points centered at $(0,0)$. Every direction from the center has equal variance. If you calculate the 1st Principal Component ($v_1$):
#
# **A)** It will point toward the densest cluster of points.
#
# **B)** It will return an error because the covariance matrix  is not invertible.
#
# **C)** The direction of $v_1$ is mathematically arbitrary (or determined by tiny noise), because no single direction captures "maximum" variance.
#
# **D)** It will always default to the X-axis.

# %% [markdown]
# Answer = (c); the direction is arbitrary (or determined by the tiny noise in the floating point representation), as no direction is able to show the correct max value.

# %% [markdown]
# **Question 2: The Scaling Trap**
# You are analyzing house data with two features: `Price` (in millions, range 0.1–5) and `SqFt` (range 500–5000). You forget to perform **Feature Normalization**.
#
# **A)** PCA will still find the true underlying relationship accurately.
#
# **B)** The 1st Principal Component will be almost entirely aligned with `SqFt` simply because the numerical values have higher variance.
#
# **C)** The eigenvalues will automatically adjust to compensate for the scale difference.
#
# **D)** The reconstruction error will become zero.

# %% [markdown]
# Answer = (b); The 1st Principal Component will be almost entirely aligned with SqFt simply because the numerical values have higher variance. PCA is sensitive to the value of features. Since SqFt has a range of 500–5000 while Price has a range of 0.1–5, the larger numerical magnitude of SqFt will dominate the covariance matrix. Data will be like a straight horizontal or verticle line and the PCA will be like that too.

# %% [markdown]
# ### **Part 2: The Geometry of Information**

# %% [markdown]
# > **How to approach Q3:** Use the **Eigenvalue Spectrum** formula. The "information" preserved is the sum of the eigenvalues you keep divided by the sum of all possible eigenvalues.

# %% [markdown]
# **Question 3: The 95% Variance Rule**
# Your total sum of eigenvalues $\sum_{i=1}^{D} \lambda_i$ is **100**. Your first three eigenvalues are $ \lambda_1 =65, \lambda_2=25$ and $\lambda_3=7$.
# If your goal is to preserve **at least 95%** of the data's variance, can you compress this data into just **2 dimensions**? Show your calculation based on the formula from **Slide 12**.

# %% [markdown]
# To preserve atleast 95% data with only 2 dimensions the formula will be -
# \[argmin(\dfrac{\sum_{i=1}^{2}\lambda_i}{100})=0.95\]
# and now we know that the sum of the first two largest eigen values are 65 and 25, therefore their sum is 90.
# \[90/100\geq0.95\]
# which is clearly not possible.
# Hence for the given eigen values it is not possible.

# %% [markdown]
# > **How to approach Q4:** Consider the size of the covariance matrix. If you have 200 images of 10,000 pixels, is it better to find the eigenvectors of a  matrix or a  matrix?
# >
# >
#
# **Question 4: The Large , Small  Problem**
# On **Slide 18**, we discuss a case with 200 images (N) of 100x100 pixels (D=10000).
# The standard covariance matrix would be 10000x10000 .
#
# 1. What is the **maximum possible rank** of this matrix? (Hint: It cannot exceed N).
#
#
# 2. If the rank is only 200, why is it computationally "expensive" to solve the 10000x10000  system directly?

# %% [markdown]
# 1. The maximum possible rank of this matrix is 200, because the rank of a covariance matrix cannot exceed the number of samples (N). Since we have 200 images, the rank is limited to min(N, D) = min(200, 10000) = 200.
#
# 2. Even though the rank is only 200, solving the 10000×10000 system directly is computationally expensive because:
#     - We need to compute and store a 10000×10000 matrix, which requires 10000² = 100,000,000 entries.
#     - Eigendecomposition of this large matrix has a time complexity of O(D^3) = O(10000^3), which is extremely slow.
#     - Most of the computational effort is wasted because only 200 eigenvectors will be non-zero or meaningful, but the algorithm doesn't know this in advance.

# %% [markdown]
# ## **Part 3: Coding Challenge — Eigen-faces with Scikit-Learn**

# %% [markdown]
# In this section, you will load a real dataset of faces, compute the PCA components, and observe how the image quality changes as we increase the number of dimensions (k).

# %% [markdown]
# **Helper functions are in the pca_utils.py file. Upload that to the session runtime by clicking on the 'Files' icon on the left pane.**
#
#
# **You are required to:**
#
# **A) Write your observations in Section 5**
#
# **B) Implement PCA using scikit-learn. Fill in the two missing lines**

# %%
import numpy as np
from sklearn.decomposition import PCA
import sys
import os

from CW8_Helper import *

# %% [markdown]
# ### SECTION 1: Loading Eigenfaces Dataset

# %%
faces, X, y, target_names, h, w = load_eigenfaces_data()
print_dataset_info(X, target_names, h, w)


plot_sample_faces(faces, y, target_names)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 faces, X, y, target_names, h, w = load_eigenfaces_data()
#       2 print_dataset_info(X, target_names, h, w)
#       5 plot_sample_faces(faces, y, target_names)
#
# File c:\Users\harsh\OneDrive\Desktop\SMAI\pca_utils.py:24, in load_eigenfaces_data()
#      13 def load_eigenfaces_data():
#      14     """
#      15     Load and return the eigenfaces dataset
#      16
#    (...)     22         h, w: height and width of images
#      23     """
# ---> 24     faces = fetch_lfw_people(min_faces_per_person=70, resize=0.4)
#      25     X = faces.data
#      26     y = faces.target
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_lfw.py:391, in fetch_lfw_people(data_home, funneled, resize, min_faces_per_person, color, slice_, download_if_missing, return_X_y, n_retries, delay)
#     251 @validate_params(
#     252     {
#     253         "data_home": [str, PathLike, None],
#    (...)    277     delay=1.0,
#     278 ):
#     279     """Load the Labeled Faces in the Wild (LFW) people dataset \
#     280 (classification).
#     281
#    (...)    389     Aaron Patterson
#     390     """
# --> 391     lfw_home, data_folder_path = _check_fetch_lfw(
#     392         data_home=data_home,
#     393         funneled=funneled,
#     394         download_if_missing=download_if_missing,
#     395         n_retries=n_retries,
#     396         delay=delay,
#     397     )
#     398     logger.debug("Loading LFW people faces from %s", lfw_home)
#     400     # wrap the loader in a memoizing function that will return memmaped data
#     401     # arrays for optimal memory usage
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_lfw.py:116, in _check_fetch_lfw(data_home, funneled, download_if_missing, n_retries, delay)
#     114 if download_if_missing:
#     115     logger.info("Downloading LFW data (~200MB): %s", archive.url)
# --> 116     _fetch_remote(
#     117         archive, dirname=lfw_home, n_retries=n_retries, delay=delay
#     118     )
#     119 else:
#     120     raise OSError("%s is missing" % archive_path)
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_base.py:1513, in _fetch_remote(remote, dirname, n_retries, delay)
#    1511 while True:
#    1512     try:
# -> 1513         urlretrieve(remote.url, temp_file_path)
#    1514         break
#    1515     except (URLError, TimeoutError):
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:270, in urlretrieve(url, filename, reporthook, data)
#     267     reporthook(blocknum, bs, size)
#     269 while True:
# --> 270     block = fp.read(bs)
#     271     if not block:
#     272         break
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\http\client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
#  ### SECTION 2: PCA from Scratch

# %%
# Step 1: Center the data
X_mean = np.mean(X, axis=0)
X_centered = X - X_mean
print(f"✓ Data centered. Mean shape: {X_mean.shape}")

# Step 2: Compute covariance matrix
cov_matrix = np.cov(X_centered.T)
print(f"✓ Covariance matrix shape: {cov_matrix.shape}")

# Step 3: Compute eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)
print(f"✓ Computed {len(eigenvalues)} eigenvalues and eigenvectors")

# Step 4: Sort by eigenvalues (descending order)
idx = eigenvalues.argsort()[::-1]
eigenvalues = eigenvalues[idx]
eigenvectors = eigenvectors[:, idx]

# Keep only real parts
eigenvalues = np.real(eigenvalues)
eigenvectors = np.real(eigenvectors)

print(f"✓ Top 5 eigenvalues: {eigenvalues[:5]}")
# Out:
# ✓ Data centered. Mean shape: (1850,)
# ✓ Covariance matrix shape: (1850, 1850)
# ✓ Computed 1850 eigenvalues and eigenvectors
# ✓ Top 5 eigenvalues: [8.41416639 5.70775293 2.83065828 2.33295885 1.98951978]

# %% [markdown]
# ### SECTION 3: Visualizing Eigenfaces

# %%
plot_eigenfaces(eigenvectors, h, w)

# %% [markdown]
# ### SECTION 4: Understanding Variance Explained
# Observe how much information does each component capture.

# %%
cumulative_variance = plot_variance_explained(eigenvalues)

# Find components needed for different variance thresholds
n_comp_90 = np.argmax(cumulative_variance >= 0.90) + 1
n_comp_95 = np.argmax(cumulative_variance >= 0.95) + 1

print(f"\n Components needed for 90% variance: {n_comp_90}")
print(f" Components needed for 95% variance: {n_comp_95}")
# Out:
#  Components needed for 90% variance: 88
#  Components needed for 95% variance: 167

# %% [markdown]
# ### SECTION 5: Face Reconstruction
# See how well we can reconstruct a face using different numbers of components. **Write your observations.**

# %%
plot_reconstruction_comparison(X, X_centered, X_mean, eigenvectors,
                              cumulative_variance, h, w, sample_idx=0)

# %% [markdown]
# - As the number of principal components increases, the reconstructed face images become clearer and more detailed.
# - With very few components, only the broadest facial features (like general shape and orientation) are visible; fine details are lost.
# - Around the 90–95% variance threshold, most facial features are recognizable, but some subtle details may still be missing.
# - Using all components restores the original image almost perfectly, but with diminishing returns in visual quality after a certain point.
# - This demonstrates that a small subset of principal components can capture most of the important information in face images, enabling significant compression with minimal loss of quality.

# %% [markdown]
# ### SECTION 6: Using Scikit-learn PCA
# Implement Scikit-learn PCA on data stored in X. Then, run the code, which will help verify our pca implementation from scratch.

# %%
n_components = 150
#Fill in here ----------------------------------

pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X)
print(f"Transformed shape: {X_pca.shape}")
print(f"Variance explained: {pca.explained_variance_ratio_.sum():.2%}")

# Verify our implementation
matches = np.allclose(eigenvalues[:5], pca.explained_variance_[:5], rtol=1e-3)
print(f"\n✓ Our implementation matches sklearn: {matches}")

# Reconstruct using sklearn
X_reconstructed = pca.inverse_transform(X_pca)

# Visualize
plot_sklearn_comparison(X, X_reconstructed, h, w, n_samples=3)
